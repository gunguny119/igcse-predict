# %%
import pandas as pd

sheet_id = "1kBPSqge0PG6TlHsk46MDq1XD-s2UNeceRxEGqGOTOgo"
sheet_name = 'Sheet1'

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(url)

# %%
df.drop(columns = ['* just components 2, 4, 6'], inplace = True)

# %%
df
# Out:
#     past papers   year  component  question number  \
# 0          March  2020         22                1
# 1          March  2020         22                2
# 2          March  2020         22                3
# 3          March  2020         22                4
# 4          March  2020         22                5
# ..           ...   ...        ...              ...
# 280        March  2020         22               36
# 281        March  2020         22               37
# 282        March  2020         22               38
# 283        March  2020         22               39
# 284        March  2020         22               40
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                             topic
# 0               Organic chemistry
# 1         Experimental techniques
# 2         Experimental techniques
# 3    Atoms,elements and compounds
# 4    Atoms,elements and compounds
# ..                            ...
# 280             Organic chemistry
# 281             Organic chemistry
# 282             Organic chemistry
# 283             Organic chemistry
# 284             Organic chemistry
#
# [285 rows x 7 columns]

# %%
df.rename(columns={'past papers ': 'month'}, inplace = True)

# %%
df[['year', 'component','question number']] = df[['year', 'component', 'question number']].astype(int)

# %%
df
# Out:
#      month  year  component  question number  \
# 0    March  2020         22                1
# 1    March  2020         22                2
# 2    March  2020         22                3
# 3    March  2020         22                4
# 4    March  2020         22                5
# ..     ...   ...        ...              ...
# 280  March  2020         22               36
# 281  March  2020         22               37
# 282  March  2020         22               38
# 283  March  2020         22               39
# 284  March  2020         22               40
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                             topic
# 0               Organic chemistry
# 1         Experimental techniques
# 2         Experimental techniques
# 3    Atoms,elements and compounds
# 4    Atoms,elements and compounds
# ..                            ...
# 280             Organic chemistry
# 281             Organic chemistry
# 282             Organic chemistry
# 283             Organic chemistry
# 284             Organic chemistry
#
# [285 rows x 7 columns]

# %%
month_map = {'march': 'm', 'june': 's', 'november': 'w'}

def convert_month(month):
    return month_map[month.strip().lower()]

df['month'] = df['month'].apply(convert_month)

# %%
df
# Out:
#     month  year  component  question number  \
# 0       m  2020         22                1
# 1       m  2020         22                2
# 2       m  2020         22                3
# 3       m  2020         22                4
# 4       m  2020         22                5
# ..    ...   ...        ...              ...
# 280     m  2020         22               36
# 281     m  2020         22               37
# 282     m  2020         22               38
# 283     m  2020         22               39
# 284     m  2020         22               40
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                             topic
# 0               Organic chemistry
# 1         Experimental techniques
# 2         Experimental techniques
# 3    Atoms,elements and compounds
# 4    Atoms,elements and compounds
# ..                            ...
# 280             Organic chemistry
# 281             Organic chemistry
# 282             Organic chemistry
# 283             Organic chemistry
# 284             Organic chemistry
#
# [285 rows x 7 columns]

# %%
import difflib
import numpy as np
real_topic_list = [
        "1 The particulate nature of matter",
        "2 Experimental techniques",
        "3 Atoms, elements and compounds",
        "4 Stoichiometry",
        "5 Electricity and chemistry",
        "6 Chemical energetics",
        "7 Chemical reactions",
        "8 Acids, bases and salts",
        "9 The Periodic Table",
        "10 Metals",
        "11 Air and water",
        "12 Sulfur",
        "13 Carbonates",
        "14 Organic chemistry",
      ]

def similar(seq1, seq2):
    return difflib.SequenceMatcher(a=seq1.lower(), b=seq2.lower()).ratio()

topics = []
for topic in df['topic']:
    if isinstance(topic, float):
        topics.append('')
        continue
    topic = topic.strip().lower()
    if topic.isdigit():
        topics.append(real_topic_list[int(topic)-1])
    else:
        similarity = []
        for real_topic in real_topic_list:
            num, name = real_topic.split(' ', 1)
            similarity.append(similar(name, topic))
        topics.append(real_topic_list[np.argmax(similarity)])

            
df['topic'] = topics

# %%
df
# Out:
#     month  year  component  question number  \
# 0       m  2020         22                1
# 1       m  2020         22                2
# 2       m  2020         22                3
# 3       m  2020         22                4
# 4       m  2020         22                5
# ..    ...   ...        ...              ...
# 280     m  2020         22               36
# 281     m  2020         22               37
# 282     m  2020         22               38
# 283     m  2020         22               39
# 284     m  2020         22               40
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
#
#                                topic
# 0               14 Organic chemistry
# 1          2 Experimental techniques
# 2          2 Experimental techniques
# 3    3 Atoms, elements and compounds
# 4    3 Atoms, elements and compounds
# ..                               ...
# 280             14 Organic chemistry
# 281             14 Organic chemistry
# 282             14 Organic chemistry
# 283             14 Organic chemistry
# 284             14 Organic chemistry
#
# [285 rows x 7 columns]

# %%
df.to_csv('component24_2020-2021_labeled.csv', index = False)
