# %%
import pandas as pd

sheet_id = "1kBPSqge0PG6TlHsk46MDq1XD-s2UNeceRxEGqGOTOgo"
sheet_name = 'Sheet1'

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(url)
df = df[['month', 'year', 'component', 'question number', 'question', 'answers', 'topic']]

# %%
df
# Out:
#         month  year  component  question number  \
# 0       March  2020         22                1
# 1       March  2020         22                2
# 2       March  2020         22                3
# 3       March  2020         22                4
# 4       March  2020         22                5
# ..        ...   ...        ...              ...
# 715  November  2019         62                4
# 716  November  2019         63                1
# 717  November  2019         63                2
# 718  November  2019         63                3
# 719  November  2019         63                4
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 715  The table gives some information about the pro...
# 716  Hydrogen peroxide, H2O2(aq), decomposes slowly...
# 717  A student investigated the reaction between di...
# 718  3 Two substances, solid U and liquid V, were a...
# 719  4 Potassium nitrate and ammonium chloride are ...
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 715                                                NaN
# 716                                                NaN
# 717                                                NaN
# 718                                                NaN
# 719                                                NaN
#
#                             topic
# 0               Organic chemistry
# 1         Experimental techniques
# 2         Experimental techniques
# 3    Atoms,elements and compounds
# 4    Atoms,elements and compounds
# ..                            ...
# 715                           NaN
# 716                           NaN
# 717                           NaN
# 718                           NaN
# 719                           NaN
#
# [720 rows x 7 columns]

# %%
df[['year', 'component','question number']] = df[['year', 'component', 'question number']].astype(int)

# %%
month_map = {'march': 'm', 'june': 's', 'november': 'w'}

def convert_month(month):
    return month_map[month.strip().lower()]

df['month'] = df['month'].apply(convert_month)

# %%
df
# Out:
#     month  year  component  question number  \
# 0       m  2020         22                1
# 1       m  2020         22                2
# 2       m  2020         22                3
# 3       m  2020         22                4
# 4       m  2020         22                5
# ..    ...   ...        ...              ...
# 715     w  2019         62                4
# 716     w  2019         63                1
# 717     w  2019         63                2
# 718     w  2019         63                3
# 719     w  2019         63                4
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 715  The table gives some information about the pro...
# 716  Hydrogen peroxide, H2O2(aq), decomposes slowly...
# 717  A student investigated the reaction between di...
# 718  3 Two substances, solid U and liquid V, were a...
# 719  4 Potassium nitrate and ammonium chloride are ...
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 715                                                NaN
# 716                                                NaN
# 717                                                NaN
# 718                                                NaN
# 719                                                NaN
#
#                             topic
# 0               Organic chemistry
# 1         Experimental techniques
# 2         Experimental techniques
# 3    Atoms,elements and compounds
# 4    Atoms,elements and compounds
# ..                            ...
# 715                           NaN
# 716                           NaN
# 717                           NaN
# 718                           NaN
# 719                           NaN
#
# [720 rows x 7 columns]

# %%
import difflib
import numpy as np
real_topic_list = [
        "1 The particulate nature of matter",
        "2 Experimental techniques",
        "3 Atoms, elements and compounds",
        "4 Stoichiometry",
        "5 Electricity and chemistry",
        "6 Chemical energetics",
        "7 Chemical reactions",
        "8 Acids, bases and salts",
        "9 The Periodic Table",
        "10 Metals",
        "11 Air and water",
        "12 Sulfur",
        "13 Carbonates",
        "14 Organic chemistry",
      ]

def similar(seq1, seq2):
    return difflib.SequenceMatcher(a=seq1.lower(), b=seq2.lower()).ratio()

topics = []
for topic in df['topic']:
    if isinstance(topic, float):
        topics.append('')
        continue
    topic = topic.strip().lower()
    if topic.isdigit():
        topics.append(real_topic_list[int(topic)-1])
    else:
        similarity = []
        for real_topic in real_topic_list:
            num, name = real_topic.split(' ', 1)
            similarity.append(similar(name, topic))
        topics.append(real_topic_list[np.argmax(similarity)])

            
df['topic'] = topics

# %%
df
# Out:
#     month  year  component  question number  \
# 0       m  2020         22                1
# 1       m  2020         22                2
# 2       m  2020         22                3
# 3       m  2020         22                4
# 4       m  2020         22                5
# ..    ...   ...        ...              ...
# 715     w  2019         62                4
# 716     w  2019         63                1
# 717     w  2019         63                2
# 718     w  2019         63                3
# 719     w  2019         63                4
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 715  The table gives some information about the pro...
# 716  Hydrogen peroxide, H2O2(aq), decomposes slowly...
# 717  A student investigated the reaction between di...
# 718  3 Two substances, solid U and liquid V, were a...
# 719  4 Potassium nitrate and ammonium chloride are ...
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 715                                                NaN
# 716                                                NaN
# 717                                                NaN
# 718                                                NaN
# 719                                                NaN
#
#                                topic
# 0               14 Organic chemistry
# 1          2 Experimental techniques
# 2          2 Experimental techniques
# 3    3 Atoms, elements and compounds
# 4    3 Atoms, elements and compounds
# ..                               ...
# 715
# 716
# 717
# 718
# 719
#
# [720 rows x 7 columns]

# %%
labeled = df[df['topic'] != '']
labeled['topic'].value_counts()
# Out:
# 14 Organic chemistry                  118
# 3 Atoms, elements and compounds        83
# 7 Chemical reactions                   67
# 10 Metals                              65
# 8 Acids, bases and salts               50
# 11 Air and water                       50
# 9 The Periodic Table                   45
# 6 Chemical energetics                  33
# 4 Stoichiometry                        31
# 2 Experimental techniques              28
# 5 Electricity and chemistry            22
# 12 Sulfur                              19
# 1 The particulate nature of matter     16
# 13 Carbonates                          10
# Name: topic, dtype: int64

# %%
labeled.fillna({'answers': '', 'question': ''}, inplace = True)
labeled['text'] = labeled['question'] + ' ' + labeled['answers']
# Out:
# /var/folders/f4/kt9d1qj51x3fbldgq930p3980000gn/T/ipykernel_1603/316589298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled.fillna({'answers': '', 'question': ''}, inplace = True)
# /var/folders/f4/kt9d1qj51x3fbldgq930p3980000gn/T/ipykernel_1603/316589298.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled['text'] = labeled['question'] + ' ' + labeled['answers']

# %%
labeled
# Out:
#     month  year  component  question number  \
# 0       m  2020         22                1
# 1       m  2020         22                2
# 2       m  2020         22                3
# 3       m  2020         22                4
# 4       m  2020         22                5
# ..    ...   ...        ...              ...
# 644     w  2021         43                3
# 645     w  2021         43                4
# 646     w  2021         43                5
# 647     w  2021         43                6
# 648     w  2021         43                7
#
#                                               question  \
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 644  Lead is a metallic element in Group IV. One of...
# 645  Carbon is an important element. (a) Carbon exi...
# 646  a) Dilute sulfuric acid and aqueous sodium hyd...
# 647  A student investigates the decomposition of hy...
# 648  12 © UCLES 2021 0620/43/O/N/21 7 (a) Ethanol i...
#
#                                                answers  \
# 0    description of diffusion relative rate of diff...
# 1    Evaporate the water to see if any solids remai...
# 2    colouring agent B display agent C finding agen...
# 3    Each fluorine atom gains one electron. B Each ...
# 4    12 6 is more reactive than C14 6 because the a...
# ..                                                 ...
# 644
# 645
# 646
# 647
# 648
#
#                                topic  \
# 0               14 Organic chemistry
# 1          2 Experimental techniques
# 2          2 Experimental techniques
# 3    3 Atoms, elements and compounds
# 4    3 Atoms, elements and compounds
# ..                               ...
# 644             9 The Periodic Table
# 645  3 Atoms, elements and compounds
# 646                        12 Sulfur
# 647             7 Chemical reactions
# 648             14 Organic chemistry
#
#                                                   text
# 0    The formula of methane is CH4 and the formula ...
# 1    Which test is used to show that a sample of wa...
# 2    Chromatography is used to separate and identif...
# 3    Lithium reacts with fluorine to form the compo...
# 4    14\n6 and C12\n6 are isotopes of carbon.\nWhic...
# ..                                                 ...
# 644  Lead is a metallic element in Group IV. One of...
# 645  Carbon is an important element. (a) Carbon exi...
# 646  a) Dilute sulfuric acid and aqueous sodium hyd...
# 647  A student investigates the decomposition of hy...
# 648  12 © UCLES 2021 0620/43/O/N/21 7 (a) Ethanol i...
#
# [637 rows x 8 columns]

# %%
labeled.drop(columns = ['question','answers'],inplace = True)
# Out:
# /var/folders/f4/kt9d1qj51x3fbldgq930p3980000gn/T/ipykernel_1603/4155878355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled.drop(columns = ['question','answers'],inplace = True)

# %%
labeled.to_csv('component24_2020-2021_labeled.csv', index=False)
